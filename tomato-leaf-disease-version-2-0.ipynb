# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
tf.random.set_seed(42)
import keras

# %% [markdown]
# # Data

# %% [markdown]
# ## Image path

# %%
train_dir = "../input/tomatoleaf/tomato/train"
test_dir = "../input/tomatoleaf/tomato/val"

# %% [markdown]
# ## Data Rescaling and augmentation

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal",
    input_shape=(112, 112, 3)),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
  tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
  tf.keras.layers.experimental.preprocessing.RandomHeight(0.2),
  tf.keras.layers.experimental.preprocessing.RandomWidth(0.2),
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
], name ="data_augmentation")

# %% [markdown]
# ## Load datasets (Shuffle and prefetch)

# %%
import tensorflow as tf

IMG_SIZE = (112, 112)
BATCH_SIZE = 32
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = train_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed=42
).cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = test_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE
)

class_names = test_data.class_names
valid_data = test_data.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 10000 files belonging to 10 classes.
# Found 1000 files belonging to 10 classes.

# %% [markdown]
# ## Visualize data

# %%
plt.figure(figsize=(18,10))
for image_batch,label_batch in train_data.take(1):
    for i in range(0,12):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        plt.title(class_names[np.argmax(label_batch[i])])
        plt.axis("off")
# Out:
# 2022-10-27 20:34:21.729590: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-10-27 20:34:31.812814: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 109 of 1000
# 2022-10-27 20:34:41.814571: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 229 of 1000
# 2022-10-27 20:34:48.241590: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.

# %% [markdown]
# ## Augmented image view

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in train_data.take(1):
    augmented_image_batch = data_augmentation(image_batch)
    image_plt_len = len(image_batch) if len(image_batch) < 4 else 4
    for i in range(0, image_plt_len):
        plt.subplot(image_plt_len,2,2*i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        plt.title(class_names[np.argmax(label_batch[i])])
        plt.axis("off")
        plt.subplot(image_plt_len,2,2*i+2)
        plt.imshow(augmented_image_batch[i])
        plt.title(f"augmented")
        plt.axis("off")

# %% [markdown]
# # Create model

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    data_augmentation,
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(16, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(len(class_names), activation='softmax', name='output_layers')

])

# %% [markdown]
# ## Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# data_augmentation (Sequentia (None, None, None, 3)     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, None, 32)    896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 16)    4624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, None, None, 16)    0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 32)    4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, None, None, 32)    0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 32)                0
# _________________________________________________________________
# output_layers (Dense)        (None, 10)                330
# =================================================================
# Total params: 10,490
# Trainable params: 10,490
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile model

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.Adam(),
    metrics = ['accuracy']
)

# %% [markdown]
# ## Fit the model

# %%
history = model.fit(
    train_data,
    epochs=100,
    steps_per_epoch=len(train_data),
    validation_data = test_data,
    validation_steps = len(test_data),
    
)
# Out:
# Epoch 1/100
# 2022-10-27 20:35:25.090291: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 313/313 [==============================] - 52s 134ms/step - loss: 2.0878 - accuracy: 0.2369 - val_loss: 1.7866 - val_accuracy: 0.3750
# Epoch 2/100
# 313/313 [==============================] - 28s 88ms/step - loss: 1.6488 - accuracy: 0.4194 - val_loss: 1.5484 - val_accuracy: 0.4410
# Epoch 3/100
# 313/313 [==============================] - 23s 74ms/step - loss: 1.4678 - accuracy: 0.4710 - val_loss: 1.3696 - val_accuracy: 0.5510
# Epoch 4/100
# 313/313 [==============================] - 17s 55ms/step - loss: 1.3567 - accuracy: 0.5225 - val_loss: 1.2259 - val_accuracy: 0.5940
# Epoch 5/100
# 313/313 [==============================] - 17s 53ms/step - loss: 1.2326 - accuracy: 0.5721 - val_loss: 1.1760 - val_accuracy: 0.6060
# Epoch 6/100
# 313/313 [==============================] - 15s 47ms/step - loss: 1.1257 - accuracy: 0.6115 - val_loss: 0.9786 - val_accuracy: 0.6800
# Epoch 7/100
# 313/313 [==============================] - 14s 44ms/step - loss: 1.0301 - accuracy: 0.6482 - val_loss: 0.9358 - val_accuracy: 0.7140
# Epoch 8/100
# 313/313 [==============================] - 11s 37ms/step - loss: 0.9462 - accuracy: 0.6767 - val_loss: 1.1071 - val_accuracy: 0.6030
# Epoch 9/100
# 313/313 [==============================] - 11s 34ms/step - loss: 0.8796 - accuracy: 0.7017 - val_loss: 0.8827 - val_accuracy: 0.6930
# Epoch 10/100
# 313/313 [==============================] - 10s 32ms/step - loss: 0.8405 - accuracy: 0.7145 - val_loss: 0.8312 - val_accuracy: 0.7350
# Epoch 11/100
# 313/313 [==============================] - 8s 25ms/step - loss: 0.7952 - accuracy: 0.7333 - val_loss: 0.8030 - val_accuracy: 0.7130
# Epoch 12/100
# 313/313 [==============================] - 8s 27ms/step - loss: 0.7677 - accuracy: 0.7431 - val_loss: 0.7733 - val_accuracy: 0.7410
# Epoch 13/100
# 313/313 [==============================] - 8s 24ms/step - loss: 0.7260 - accuracy: 0.7556 - val_loss: 0.7969 - val_accuracy: 0.7400
# Epoch 14/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.7201 - accuracy: 0.7620 - val_loss: 0.6364 - val_accuracy: 0.7900
# Epoch 15/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7015 - accuracy: 0.7652 - val_loss: 0.7144 - val_accuracy: 0.7500
# Epoch 16/100
# 313/313 [==============================] - 6s 21ms/step - loss: 0.6893 - accuracy: 0.7658 - val_loss: 0.6337 - val_accuracy: 0.7970
# Epoch 17/100
# 313/313 [==============================] - 6s 21ms/step - loss: 0.6556 - accuracy: 0.7846 - val_loss: 0.7365 - val_accuracy: 0.7570
# Epoch 18/100
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6583 - accuracy: 0.7800 - val_loss: 0.6385 - val_accuracy: 0.7880
# Epoch 19/100
# 313/313 [==============================] - 5s 17ms/step - loss: 0.6188 - accuracy: 0.7916 - val_loss: 0.6191 - val_accuracy: 0.7950
# Epoch 20/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.6121 - accuracy: 0.8004 - val_loss: 0.6718 - val_accuracy: 0.7800
# Epoch 21/100
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6136 - accuracy: 0.7955 - val_loss: 0.6961 - val_accuracy: 0.7760
# Epoch 22/100
# 313/313 [==============================] - 6s 18ms/step - loss: 0.5680 - accuracy: 0.8150 - val_loss: 0.7013 - val_accuracy: 0.7750
# Epoch 23/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.5736 - accuracy: 0.8087 - val_loss: 0.6121 - val_accuracy: 0.8120
# Epoch 24/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5584 - accuracy: 0.8137 - val_loss: 0.5700 - val_accuracy: 0.8150
# Epoch 25/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5389 - accuracy: 0.8220 - val_loss: 0.6476 - val_accuracy: 0.7840
# Epoch 26/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5179 - accuracy: 0.8279 - val_loss: 0.6046 - val_accuracy: 0.8010
# Epoch 27/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5305 - accuracy: 0.8270 - val_loss: 0.5994 - val_accuracy: 0.7920
# Epoch 28/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5175 - accuracy: 0.8300 - val_loss: 0.6824 - val_accuracy: 0.7820
# Epoch 29/100
# 313/313 [==============================] - 5s 16ms/step - loss: 0.5077 - accuracy: 0.8299 - val_loss: 0.5675 - val_accuracy: 0.8270
# Epoch 30/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4872 - accuracy: 0.8337 - val_loss: 0.6761 - val_accuracy: 0.7750
# Epoch 31/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4972 - accuracy: 0.8365 - val_loss: 0.6338 - val_accuracy: 0.7860
# Epoch 32/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4805 - accuracy: 0.8358 - val_loss: 0.5308 - val_accuracy: 0.8170
# Epoch 33/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4858 - accuracy: 0.8383 - val_loss: 0.5394 - val_accuracy: 0.8260
# Epoch 34/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4728 - accuracy: 0.8410 - val_loss: 0.5550 - val_accuracy: 0.8190
# Epoch 35/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4600 - accuracy: 0.8467 - val_loss: 0.4543 - val_accuracy: 0.8540
# Epoch 36/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4582 - accuracy: 0.8475 - val_loss: 0.6425 - val_accuracy: 0.7900
# Epoch 37/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4614 - accuracy: 0.8449 - val_loss: 0.6984 - val_accuracy: 0.7750
# Epoch 38/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4554 - accuracy: 0.8491 - val_loss: 0.6130 - val_accuracy: 0.7940
# Epoch 39/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4397 - accuracy: 0.8544 - val_loss: 0.6043 - val_accuracy: 0.8070
# Epoch 40/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4486 - accuracy: 0.8514 - val_loss: 0.5166 - val_accuracy: 0.8300
# Epoch 41/100
# 313/313 [==============================] - 5s 14ms/step - loss: 0.4347 - accuracy: 0.8554 - val_loss: 0.6102 - val_accuracy: 0.8080
# Epoch 42/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4489 - accuracy: 0.8503 - val_loss: 0.6238 - val_accuracy: 0.7980
# Epoch 43/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4265 - accuracy: 0.8570 - val_loss: 0.5046 - val_accuracy: 0.8250
# Epoch 44/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4157 - accuracy: 0.8616 - val_loss: 0.6513 - val_accuracy: 0.7970
# Epoch 45/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4110 - accuracy: 0.8649 - val_loss: 0.8395 - val_accuracy: 0.7440
# Epoch 46/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4133 - accuracy: 0.8637 - val_loss: 0.6125 - val_accuracy: 0.8110
# Epoch 47/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4175 - accuracy: 0.8613 - val_loss: 0.6437 - val_accuracy: 0.7910
# Epoch 48/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3880 - accuracy: 0.8702 - val_loss: 0.4539 - val_accuracy: 0.8520
# Epoch 49/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4058 - accuracy: 0.8664 - val_loss: 0.6395 - val_accuracy: 0.7950
# Epoch 50/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3959 - accuracy: 0.8704 - val_loss: 0.5456 - val_accuracy: 0.8150
# Epoch 51/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3929 - accuracy: 0.8698 - val_loss: 0.6831 - val_accuracy: 0.7920
# Epoch 52/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3828 - accuracy: 0.8713 - val_loss: 0.6115 - val_accuracy: 0.8000
# Epoch 53/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3887 - accuracy: 0.8706 - val_loss: 0.5479 - val_accuracy: 0.8240
# Epoch 54/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3698 - accuracy: 0.8793 - val_loss: 0.4691 - val_accuracy: 0.8540
# Epoch 55/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3814 - accuracy: 0.8739 - val_loss: 0.6867 - val_accuracy: 0.7970
# Epoch 56/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3842 - accuracy: 0.8730 - val_loss: 0.7214 - val_accuracy: 0.7670
# Epoch 57/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3796 - accuracy: 0.8707 - val_loss: 0.5303 - val_accuracy: 0.8360
# Epoch 58/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3716 - accuracy: 0.8775 - val_loss: 0.4908 - val_accuracy: 0.8470
# Epoch 59/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3675 - accuracy: 0.8762 - val_loss: 0.6350 - val_accuracy: 0.8010
# Epoch 60/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3729 - accuracy: 0.8746 - val_loss: 0.7284 - val_accuracy: 0.7670
# Epoch 61/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3623 - accuracy: 0.8781 - val_loss: 1.0004 - val_accuracy: 0.7080
# Epoch 62/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3551 - accuracy: 0.8805 - val_loss: 0.7223 - val_accuracy: 0.7800
# Epoch 63/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3636 - accuracy: 0.8761 - val_loss: 0.9583 - val_accuracy: 0.7250
# Epoch 64/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3709 - accuracy: 0.8784 - val_loss: 1.2634 - val_accuracy: 0.6730
# Epoch 65/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3599 - accuracy: 0.8807 - val_loss: 0.9941 - val_accuracy: 0.7220
# Epoch 66/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3534 - accuracy: 0.8838 - val_loss: 0.6045 - val_accuracy: 0.8180
# Epoch 67/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3581 - accuracy: 0.8846 - val_loss: 0.7565 - val_accuracy: 0.7600
# Epoch 68/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3558 - accuracy: 0.8835 - val_loss: 0.7557 - val_accuracy: 0.7710
# Epoch 69/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3571 - accuracy: 0.8819 - val_loss: 0.5339 - val_accuracy: 0.8340
# Epoch 70/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3510 - accuracy: 0.8818 - val_loss: 0.5187 - val_accuracy: 0.8340
# Epoch 71/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3381 - accuracy: 0.8910 - val_loss: 0.5259 - val_accuracy: 0.8280
# Epoch 72/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3430 - accuracy: 0.8876 - val_loss: 0.8149 - val_accuracy: 0.7530
# Epoch 73/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3357 - accuracy: 0.8911 - val_loss: 0.4423 - val_accuracy: 0.8630
# Epoch 74/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3468 - accuracy: 0.8869 - val_loss: 0.6259 - val_accuracy: 0.8070
# Epoch 75/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3369 - accuracy: 0.8870 - val_loss: 0.6076 - val_accuracy: 0.8100
# Epoch 76/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3346 - accuracy: 0.8852 - val_loss: 0.5099 - val_accuracy: 0.8430
# Epoch 77/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3306 - accuracy: 0.8906 - val_loss: 0.4368 - val_accuracy: 0.8560
# Epoch 78/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3437 - accuracy: 0.8850 - val_loss: 0.6994 - val_accuracy: 0.7850
# Epoch 79/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3279 - accuracy: 0.8909 - val_loss: 0.5417 - val_accuracy: 0.8260
# Epoch 80/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3395 - accuracy: 0.8859 - val_loss: 0.7425 - val_accuracy: 0.7770
# Epoch 81/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3262 - accuracy: 0.8937 - val_loss: 0.4172 - val_accuracy: 0.8600
# Epoch 82/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3263 - accuracy: 0.8943 - val_loss: 0.6830 - val_accuracy: 0.7940
# Epoch 83/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3159 - accuracy: 0.8934 - val_loss: 0.8655 - val_accuracy: 0.7510
# Epoch 84/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3229 - accuracy: 0.8908 - val_loss: 0.9898 - val_accuracy: 0.7190
# Epoch 85/100
# 313/313 [==============================] - 5s 14ms/step - loss: 0.3199 - accuracy: 0.8956 - val_loss: 0.7449 - val_accuracy: 0.7870
# Epoch 86/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3198 - accuracy: 0.8942 - val_loss: 0.6681 - val_accuracy: 0.7930
# Epoch 87/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3095 - accuracy: 0.8941 - val_loss: 0.6469 - val_accuracy: 0.8010
# Epoch 88/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3151 - accuracy: 0.8930 - val_loss: 0.8189 - val_accuracy: 0.7690
# Epoch 89/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3166 - accuracy: 0.8978 - val_loss: 0.7667 - val_accuracy: 0.7690
# Epoch 90/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3155 - accuracy: 0.8906 - val_loss: 0.4155 - val_accuracy: 0.8660
# Epoch 91/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3213 - accuracy: 0.8907 - val_loss: 0.6633 - val_accuracy: 0.7930
# Epoch 92/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3124 - accuracy: 0.9000 - val_loss: 0.4300 - val_accuracy: 0.8590
# Epoch 93/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3043 - accuracy: 0.8974 - val_loss: 0.5050 - val_accuracy: 0.8440
# Epoch 94/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3079 - accuracy: 0.8998 - val_loss: 0.6834 - val_accuracy: 0.7980
# Epoch 95/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3027 - accuracy: 0.8970 - val_loss: 0.4955 - val_accuracy: 0.8490
# Epoch 96/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3031 - accuracy: 0.8986 - val_loss: 0.4330 - val_accuracy: 0.8630
# Epoch 97/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3054 - accuracy: 0.8946 - val_loss: 0.6253 - val_accuracy: 0.8070
# Epoch 98/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3057 - accuracy: 0.8979 - val_loss: 0.5281 - val_accuracy: 0.8270
# Epoch 99/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3022 - accuracy: 0.8961 - val_loss: 0.6535 - val_accuracy: 0.8130
# Epoch 100/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3013 - accuracy: 0.9000 - val_loss: 0.5404 - val_accuracy: 0.8360

# %% [markdown]
# # Create plot_loss_curve function

# %%
def plot_loss_curves(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    epochs = range(len(history.history['loss']))

    plt.figure(figsize=(12,6))
  # Plot loss
    plt.subplot(1,2,1)
    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

  # Plot accuracy
    plt.subplot(1,2,2)
    plt.plot(epochs, accuracy, label='training_accuracy')
    plt.plot(epochs, val_accuracy, label='val_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend()

# %% [markdown]
# ## plot the model

# %%
plot_loss_curves(history)

# %% [markdown]
# # Evaluate model

# %%
model.evaluate(test_data)
# Out:
# 32/32 [==============================] - 1s 22ms/step - loss: 0.5404 - accuracy: 0.8360
# [0.5403986573219299, 0.8360000252723694]

# %% [markdown]
# ### Evaluate

# %%
model.evaluate(train_data), model.evaluate(test_data)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4412 - accuracy: 0.8566
# 32/32 [==============================] - 1s 21ms/step - loss: 0.5404 - accuracy: 0.8360
# ([0.4412430226802826, 0.8565999865531921],
#  [0.5403984785079956, 0.8360000252723694])

# %%
model.save('Tomato_disease_2.h5')

# %% [markdown]
# ## Load model

# %%
import keras

# %%
load_model = tf.keras.models.load_model("Tomato_disease_2.h5")

# %%
plt.figure(figsize=(18,12))
for image_batch,label_batch in test_data.take(1):
    predictions = load_model.predict(image_batch)
    predictions = np.argmax(predictions, axis=-1)
    for i in range(0,len(predictions) if len(predictions)<12 else 12):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        true_class = class_names[np.argmax(label_batch[i])]
        predict_class = class_names[predictions[i]]
        title = f"""True: {true_class}\n Predict: {predict_class}"""
        plt.title(title, color='g' if true_class==predict_class else 'r')
        plt.axis("off")

# %% [markdown]
# # Confusion matrix

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False): 
  
  # Create the confustion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
    n_classes = cm.shape[0] # find the number of classes we're dealing with
  # Plot the figure and make it pretty
    fig, ax = plt.subplots(figsize=figsize)
    cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
    fig.colorbar(cax)

  # Are there a list of classes?
    if classes:
        labels = classes
    else:
        labels = np.arange(cm.shape[0])
  
  # Label the axes
    ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels,
         )
  
  # Make x-axis labels appear on bottom
    ax.tick_params(axis='x', labelrotation=90)
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()

  # Set the threshold for different colors
    threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if norm:
              plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)
        else:
              plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

# %% [markdown]
# ## Predict y_pred and get y_true

# %%
y_true = np.array([])
y_pred = np.array([])
for x, y in test_data:
    y_true = np.concatenate([y_true, np.argmax(y, axis=-1)], axis=0)
    y_pred = np.concatenate([y_pred, np.argmax(load_model.predict(x), axis=-1)], axis=0)

# %% [markdown]
# ## Plot confusion matrix

# %%
make_confusion_matrix(y_true, y_pred, class_names)
